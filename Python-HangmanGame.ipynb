# %% [markdown]
# Hangman Game--
#
# The computer takes random state name in india from input.You have to guess the state name in less then 10 attempts.You have to guess the state name in single letters only(Ex-a,b,c...).If you can't guess you will be hanged.If you guess you will win.

# %%
#import function is used to import a module called random
import random
#def is used to define a function
def hangman():
#random.choice gives any random word from the list in the given input 
    states=random.choice(["punjab","telangana","kerala","gujarat","goa","haryana","manipur","odisha","karnataka","rajasthan","tripura",
    "sikkim","nagaland","mizoram"])
    Number_of_turns=10
    validLetters='abcdefghijklmnopqrstuvwxyz'
    guess_attempt=''
    while len(states) > 0:
        prime= ""
        missed = 0
        for i in states:
# used if-else conditions
            if i in guess_attempt:
                prime=prime+i
            else:
                prime=prime+"_"+" "
        if prime==states:
            print("It's corret" ,prime)
            print("You win!")
            print("Your brilliant")
            break
        print("Guess the state:" , prime)
        guess = input()
#here "if" condition is used if guess is correct it fills the blanks
        if guess in validLetters:
            guess_attempt = guess_attempt + guess
#here "else" condition is used if you guess in words it gives to enter a valid letter. 
        else:
            print("Enter a valid letter")
            guess = input()
        if guess not in states:
            Number_of_turns = Number_of_turns - 1
            if Number_of_turns == 9:
                print("only 9 turns left")
                print("wrong guess sorry!")
                print("--------------")
            if Number_of_turns == 8:
                print("only 8 turns left")
                print("wrong guess sorry!")
                print("     O      ")
            if Number_of_turns == 7:
                print("only 7 turns left")
                print("wrong guess sorry!")
                print("-------------")
                print("             ")
                print("     O      ")
                print("     |      ")
            if Number_of_turns == 6:
                print("only 6 turns left")
                print("wrong guess sorry!")
                print("-------------")
                print("             ")
                print("     O      ")
                print("     |      ")
                print("      \     ")
                print("------------")
            if Number_of_turns == 5:
                print("only 5 turns left")
                print("wrong guess sorry!")
                print("-------------")
                print("             ")
                print("     O      ")
                print("     |      ")
                print("    / \     ")
                print("------------")
            if Number_of_turns == 4:
                print("only 4 turns left")
                print("wrong guess sorry!")
                print("----------------")
                print("             ")
                print("     O /     ")
                print("     |      ")
                print("    / \     ")
                print("------------")
            if Number_of_turns == 3:
                print("only 3 turns left")
                print("wrong guess sorry!")
                print("--------------")
                print("             ")
                print("   \ O /    ")
                print("     |      ")
                print("    / \     ")
                print("------------")
            if Number_of_turns == 2:
                print("only 2 turns left")
                print("wrong guess sorry!")
                print("  ---------  ")
                print("       |    ")
                print("   \ O /   ")
                print("     |      ")
                print("    / \     ")
                print("------------")
            if Number_of_turns == 1:
                print("only 1 turns left")
                print("wrong guess sorry!")
                print("Its your last oxygen point left")
                print("  ---------  ")
                print("   \ O /|   ")
                print("     |      ")
                print("    / \     ")
                print("   |||||          ")
                print("------------")
            if Number_of_turns == 0:
                print("You were not able to guess")
                print("You Died")
                print("  -------------  ")
                print("        O_|    ")
                print("       /|\      ")
                print("       / \     ")
                print(" ||||           ")
                print("-------------")
                print("Answer is",states)
                break
Name=input("Enter your name: ")
print("Welcome" , Name )
print("Guess the word in less than 10 attempts")
print("Hint:It is one of the state in INDIA.")
hangman()
print()
# Out:
# Enter your name: rit
# Welcome rit
# Guess the word in less than 10 attempts
# Hint:It is one of the state in INDIA.
# Guess the state: _ _ _ _ _ _ _
# a
# Guess the state: _ a_ _ a_ a
# f
# only 9 turns left
# wrong guess sorry!
# --------------
# Guess the state: _ a_ _ a_ a
# k
# only 8 turns left
# wrong guess sorry!
#      O
# Guess the state: _ a_ _ a_ a
# o
# only 7 turns left
# wrong guess sorry!
# -------------
#
#      O
#      |
# Guess the state: _ a_ _ a_ a
# p
# only 6 turns left
# wrong guess sorry!
# -------------
#
#      O
#      |
#       \
# ------------
# Guess the state: _ a_ _ a_ a
# y
# Guess the state: _ a_ ya_ a
# e
# only 5 turns left
# wrong guess sorry!
# -------------
#
#      O
#      |
#     / \
# ------------
# Guess the state: _ a_ ya_ a
# r
# Guess the state: _ arya_ a
# t
# only 4 turns left
# wrong guess sorry!
# ----------------
#
#      O /
#      |
#     / \
# ------------
# Guess the state: _ arya_ a
# y
# Guess the state: _ arya_ a
# u
# ...
